# %% [markdown]
# # Task 3

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from joblib import dump, load
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 16, 'axes.labelweight': 'bold', 'figure.figsize': (8,6)})
## add any other additional packages that you need. You are free to use any packages for vizualization.

# %% [markdown]
# ## Part 1:

# %% [markdown]
# Recall as a final goal of this project. We want to build and deploy ensemble machine learning models in the cloud, where features are outputs of different climate models and the target is the actual rainfall observation. In this milestone, you'll actually build these ensemble machine learning models in the cloud.
#
# **Your tasks:**
#
# 1. Read the data CSV from your s3 bucket.
# 2. Drop rows with nans.
# 3. Split the data into train (80%) and test (20%) portions with `random_state=123`.
# 4. Carry out EDA of your choice on the train split.
# 5. Train ensemble machine learning model using `RandomForestRegressor` and evaluate with metric of your choice (e.g., `RMSE`) by considering `Observed` as the target column.
# 6. Discuss your results. Are you getting better results with ensemble models compared to the individual climate models?
#
# > Recall that individual columns in the data are predictions of different climate models.

# %%
## Depending on the permissions that you provided to your bucket you might need to provide your aws credentials
## to read from the bucket, if so provide with your credentials and pass as storage_options=aws_credentials
# aws_credentials = {"key": "","secret": "","token":""}
df = pd.read_csv("s3://mds-s3-08/output/ml_data_SYD.csv", index_col=0, parse_dates=True)

# %%
## Use your ML skills to get from step 1 to step 6

# %%
# drop rows with nans
df = df.dropna()

# train test split
train, test = train_test_split(df, test_size=0.2, random_state=123)

# separate into X and y
X_train, y_train = train.drop(columns="observed_rainfall"), train["observed_rainfall"]
X_test, y_test = test.drop(columns="observed_rainfall"), test["observed_rainfall"]

# %%
train.describe().T.round(5)
# Out:
#                      count     mean      std  min      25%      50%      75%  \
# ACCESS-CM2         36791.0  2.42942  6.79137  0.0  0.05411  0.19298  1.44546
# ACCESS-ESM1-5      36791.0  2.93896  7.04879  0.0  0.02125  0.49276  2.39854
# AWI-ESM-1-1-LR     36791.0  3.71633  7.28086  0.0  0.02962  0.59231  3.60170
# BCC-CSM2-MR        36791.0  2.20309  6.51822  0.0  0.00051  0.09644  1.31894
# BCC-ESM1           36791.0  2.74844  5.99744  0.0  0.00238  0.29865  2.47789
# CMCC-CM2-HR4       36791.0  3.09278  6.45925  0.0  0.13832  0.63355  3.18263
# CMCC-CM2-SR5       36791.0  3.57520  7.35345 -0.0  0.08899  0.82789  3.72770
# CMCC-ESM2          36791.0  3.48976  7.03920 -0.0  0.09271  0.84862  3.62996
# CanESM5            36791.0  2.87934  6.89889  0.0  0.02249  0.33761  2.55885
# EC-Earth3-Veg-LR   36791.0  2.56543  5.73274 -0.0  0.01202  0.42968  2.29585
# FGOALS-g3          36791.0  1.73585  4.47261  0.0  0.02712  0.28541  1.33566
# ...

# %%
train["observed_rainfall"].hist(bins=50)
plt.title("Distribution of Observed Rainfall")
plt.xlabel("Rainfall")
plt.ylabel("Count");

# %%
rf = RandomForestRegressor(random_state=123)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=123)

# %%
y_pred = rf.predict(X_test)
mean_squared_error(y_true = y_test, y_pred = y_pred, squared = False)
# Out:
# 8.860047622369347

# %%
all_rmse = {}

for col in X_train.columns:
    rmse = mean_squared_error(y_true = y_test, y_pred = test[col], squared = False)
    all_rmse[col] = rmse

rmse_df = pd.DataFrame(all_rmse.values(), index=all_rmse.keys(), columns=["RMSE"])
rmse_df.sort_values("RMSE")
# Out:
#                        RMSE
# KIOST-ESM          9.600480
# FGOALS-g3          9.687788
# MRI-ESM2-0         9.922795
# MPI-ESM1-2-HR      9.969823
# NESM3              9.978137
# MPI-ESM1-2-LR     10.260886
# NorESM2-LM        10.410145
# EC-Earth3-Veg-LR  10.453606
# GFDL-CM4          10.511682
# BCC-ESM1          10.615578
# CMCC-CM2-HR4      10.643204
# ACCESS-ESM1-5     10.695305
# BCC-CSM2-MR       10.761381
# MPI-ESM-1-2-HAM   10.932004
# NorESM2-MM        10.939740
# AWI-ESM-1-1-LR    10.996616
# ACCESS-CM2        11.038999
# CanESM5           11.151318
# CMCC-ESM2         11.246493
# MIROC6            11.352976
# INM-CM4-8         11.451635
# CMCC-CM2-SR5      11.480614
# TaiESM1           11.528083
# SAM0-UNICON       11.678749
# INM-CM5-0         12.250223

# %% [markdown]
# **Discussion of results**
#
# Yes - our RMSE with our `RandomForestRegressor` is `8.86` which is lower the RMSE of any of the individual climate models.

# %% [markdown]
# ## Part 2:

# %% [markdown]
# ### Preparation for deploying model next week

# %% [markdown]
# ***NOTE: Complete task 4 from the milestone3 before coming here***

# %% [markdown]
# We’ve found the best hyperparameter settings with MLlib (from the task 4 from milestone3), we then use the same hyperparameters to train a scikit-learn model.

# %%
model = RandomForestRegressor(n_estimators=100, max_depth=5, bootstrap=False)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=5)

# %%
print(f"Train RMSE: {mean_squared_error(y_train, model.predict(X_train), squared=False):.2f}")
print(f" Test RMSE: {mean_squared_error(y_test, model.predict(X_test), squared=False):.2f}")
# Out:
# Train RMSE: 7.91
#  Test RMSE: 8.71

# %%
# ready to deploy
dump(model, "model.joblib")
# Out:
# ['model.joblib']

# %% [markdown]
# ***Upload model.joblib to s3 under output folder. You choose how you want to upload it (using CLI, SDK, or web console).***
#
# ![Milestone3_Task_3.png](image/Milestone3_Task_3.png)
